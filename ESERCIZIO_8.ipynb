# %%
import dotenv
import os
from sqlalchemy import create_engine
import pandas as pd
dotenv.load_dotenv()
username=os.getenv("usernames")
password=os.getenv("password")
host=os.getenv("host")
dbname=os.getenv("dbname")
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """ SELECT * FROM dimproduct
"""
df = pd.read_sql(query, db_engine)
db_engine.dispose()
df.shape
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             606 non-null    int64
#  1   ProductAlternateKey    606 non-null    object
#  2   ProductSubcategoryKey  397 non-null    float64
#  3   WeightUnitMeasureCode  282 non-null    object
#  4   SizeUnitMeasureCode    253 non-null    object
#  5   EnglishProductName     606 non-null    object
#  6   SpanishProductName     606 non-null    object
#  7   FrenchProductName      606 non-null    object
#  8   StandardCost           397 non-null    float64
#  9   FinishedGoodsFlag      606 non-null    int64
#  10  Color                  606 non-null    object
#  11  SafetyStockLevel       606 non-null    int64
#  12  ReorderPoint           606 non-null    int64
#  13  ListPrice              395 non-null    float64
# ...

# %%
df['DealerPrice'] = df['DealerPrice'].round(2)

# %%
df['DealerPrice']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 601     60.74
# 602     72.89
# 603    323.99
# 604    323.99
# 605    323.99
# Name: DealerPrice, Length: 606, dtype: float64

# %%
df['DealerPrice'] = df['DealerPrice'].round(0)

# %%
df['DealerPrice']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 601     61.0
# 602     73.0
# 603    324.0
# 604    324.0
# 605    324.0
# Name: DealerPrice, Length: 606, dtype: float64

# %%
df['DealerPrice'] = df['DealerPrice'].clip(lower=0, upper=1000)

# %%
df['DealerPrice']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 601     61.0
# 602     73.0
# 603    324.0
# 604    324.0
# 605    324.0
# Name: DealerPrice, Length: 606, dtype: float64

# %%
df['DealerPrice'].min(),df['DealerPrice'].max()
# Out:
# (1.0, 1000.0)

# %%
import numpy as np

# %%
years = 5 
a = pd.DataFrame({"Mese": list("GFMAMGLASOND"*years),                
                            "Anno": np.repeat(list(range(years)), 12),                
                            "Guadagni": np.random.randint(800, 5000, 12*years)})

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Mese      60 non-null     object
#  1   Anno      60 non-null     int32
#  2   Guadagni  60 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 1.1+ KB

# %%
a['Guadagni_cum'] = a['Guadagni'].cumsum()

# %%
a
# Out:
#    Mese  Anno  Guadagni  Guadagni_cum  Guadagni_cum_x_anno
# 0     G     0      3663          3663                 3663
# 1     F     0      4933          8596                 4933
# 2     M     0      3627         12223                 3627
# 3     A     0      3881         16104                 3881
# 4     M     0      1672         17776                 5299
# 5     G     0      3668         21444                 7331
# 6     L     0      4885         26329                 4885
# 7     A     0      2991         29320                 6872
# 8     S     0      1860         31180                 1860
# 9     O     0      2264         33444                 2264
# 10    N     0      3199         36643                 3199
# 11    D     0      3184         39827                 3184
# 12    G     1      1615         41442                 1615
# 13    F     1      2286         43728                 2286
# 14    M     1      3006         46734                 3006
# ...

# %%
a['Guadagni_x_anno'] = a.groupby('Anno')['Guadagni'].cumsum()

# %%
a
# Out:
#    Mese  Anno  Guadagni  Guadagni_cum  Guadagni_cum_x_anno  Guadagni_x_anno
# 0     G     0      3663          3663                 3663             3663
# 1     F     0      4933          8596                 4933             8596
# 2     M     0      3627         12223                 3627            12223
# 3     A     0      3881         16104                 3881            16104
# 4     M     0      1672         17776                 5299            17776
# 5     G     0      3668         21444                 7331            21444
# 6     L     0      4885         26329                 4885            26329
# 7     A     0      2991         29320                 6872            29320
# 8     S     0      1860         31180                 1860            31180
# 9     O     0      2264         33444                 2264            33444
# 10    N     0      3199         36643                 3199            36643
# ...

# %%
query = """ SELECT * FROM dimcustomer
"""
df = pd.read_sql(query, db_engine)

# %%
df
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000  None        Jon
# 1            11001            37           AW00011001  None     Eugene
# 2            11002            31           AW00011002  None      Ruben
# 3            11003            11           AW00011003  None    Christy
# 4            11004            19           AW00011004  None  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           209           AW00029479  None      Tommy
# 18480        29480           248           AW00029480  None       Nina
# 18481        29481           120           AW00029481  None       Ivan
# 18482        29482           179           AW00029482  None    Clayton
# 18483        29483           217           AW00029483  None      Jésus
#
#       MiddleName LastName  NameStyle   BirthDate MaritalStatus  ...  \
# ...

# %%
df['FirstName'] = df['FirstName'].str.lower()
df['LastName'] = df['LastName'].str.upper()

# %%
df
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000  None        jon
# 1            11001            37           AW00011001  None     eugene
# 2            11002            31           AW00011002  None      ruben
# 3            11003            11           AW00011003  None    christy
# 4            11004            19           AW00011004  None  elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           209           AW00029479  None      tommy
# 18480        29480           248           AW00029480  None       nina
# 18481        29481           120           AW00029481  None       ivan
# 18482        29482           179           AW00029482  None    clayton
# 18483        29483           217           AW00029483  None      jésus
#
#       MiddleName LastName  NameStyle   BirthDate MaritalStatus  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerKey           18484 non-null  int64
#  1   GeographyKey          18484 non-null  int64
#  2   CustomerAlternateKey  18484 non-null  object
#  3   Title                 101 non-null    object
#  4   FirstName             18484 non-null  object
#  5   MiddleName            10654 non-null  object
#  6   LastName              18484 non-null  object
#  7   NameStyle             18484 non-null  int64
#  8   BirthDate             18484 non-null  object
#  9   MaritalStatus         18484 non-null  object
#  10  Suffix                3 non-null      object
#  11  Gender                18484 non-null  object
#  12  EmailAddress          18484 non-null  object
#  13  YearlyIncome          18484 non-null  float64
#  14  TotalChildren         18484 non-null  int64
# ...

# %%
df['EmailAddress']
# Out:
# 0             jon24@adventure-works.com
# 1          eugene10@adventure-works.com
# 2           ruben35@adventure-works.com
# 3         christy12@adventure-works.com
# 4        elizabeth5@adventure-works.com
#                       ...
# 18479        tommy2@adventure-works.com
# 18480        nina21@adventure-works.com
# 18481         ivan0@adventure-works.com
# 18482      clayton0@adventure-works.com
# 18483        jésus9@adventure-works.com
# Name: EmailAddress, Length: 18484, dtype: object

# %%
df['Nome_utente'] = df['EmailAddress'].str.split('@')

# %%
df['Nome_utente']
# Out:
# 0             [jon24, adventure-works.com]
# 1          [eugene10, adventure-works.com]
# 2           [ruben35, adventure-works.com]
# 3         [christy12, adventure-works.com]
# 4        [elizabeth5, adventure-works.com]
#                        ...
# 18479        [tommy2, adventure-works.com]
# 18480        [nina21, adventure-works.com]
# 18481         [ivan0, adventure-works.com]
# 18482      [clayton0, adventure-works.com]
# 18483        [jésus9, adventure-works.com]
# Name: Nome_utente, Length: 18484, dtype: object

# %%
df.rename(columns ={'Nome_utente': 'Nome_utente + dominio'})
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000  None        jon
# 1            11001            37           AW00011001  None     eugene
# 2            11002            31           AW00011002  None      ruben
# 3            11003            11           AW00011003  None    christy
# 4            11004            19           AW00011004  None  elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           209           AW00029479  None      tommy
# 18480        29480           248           AW00029480  None       nina
# 18481        29481           120           AW00029481  None       ivan
# 18482        29482           179           AW00029482  None    clayton
# 18483        29483           217           AW00029483  None      jésus
#
#       MiddleName LastName  NameStyle   BirthDate MaritalStatus  ...  \
# ...

# %%
df['Splitted'] = df['Phone'].str.split()

# %%
df['Splitted']
# Out:
# 0        [1, (11), 500, 555-0162]
# 1        [1, (11), 500, 555-0110]
# 2        [1, (11), 500, 555-0184]
# 3        [1, (11), 500, 555-0162]
# 4        [1, (11), 500, 555-0131]
#                    ...
# 18479    [1, (11), 500, 555-0136]
# 18480    [1, (11), 500, 555-0146]
# 18481    [1, (11), 500, 555-0144]
# 18482    [1, (11), 500, 555-0137]
# 18483    [1, (11), 500, 555-0141]
# Name: Splitted, Length: 18484, dtype: object

# %%
df.loc[df['EmailAddress'].str.contains('21'), ['EmailAddress']]
# Out:
#                          EmailAddress
# 64        chase21@adventure-works.com
# 118       alvin21@adventure-works.com
# 130    caroline21@adventure-works.com
# 163     gabriel21@adventure-works.com
# 203        luis21@adventure-works.com
# ...                               ...
# 18337    hector21@adventure-works.com
# 18365    cheryl21@adventure-works.com
# 18435   stanley21@adventure-works.com
# 18440    rafael21@adventure-works.com
# 18480      nina21@adventure-works.com
#
# [431 rows x 1 columns]

# %%
filtro_email = df[df['EmailAddress'].str.contains('21')]

filtro_email[['EmailAddress']]
# Out:
#                          EmailAddress
# 64        chase21@adventure-works.com
# 118       alvin21@adventure-works.com
# 130    caroline21@adventure-works.com
# 163     gabriel21@adventure-works.com
# 203        luis21@adventure-works.com
# ...                               ...
# 18337    hector21@adventure-works.com
# 18365    cheryl21@adventure-works.com
# 18435   stanley21@adventure-works.com
# 18440    rafael21@adventure-works.com
# 18480      nina21@adventure-works.com
#
# [431 rows x 1 columns]

# %%
filtro_email2 = df[df['EmailAddress'].str.contains('10|20')]
filtro_email2[['EmailAddress']]
# Out:
#                            EmailAddress
# 1          eugene10@adventure-works.com
# 10      jacquelyn20@adventure-works.com
# 22          ethan20@adventure-works.com
# 30        bethany10@adventure-works.com
# 32         denise10@adventure-works.com
# ...                                 ...
# 18395       lydia10@adventure-works.com
# 18397      walter10@adventure-works.com
# 18415       oscar20@adventure-works.com
# 18418     lindsey10@adventure-works.com
# 18428  kristopher20@adventure-works.com
#
# [1042 rows x 1 columns]

# %%
df['email_len'] = df['EmailAddress'].str.len()

# %%
df['email_len']
# Out:
# 0        25
# 1        28
# 2        27
# 3        29
# 4        30
#          ..
# 18479    26
# 18480    26
# 18481    25
# 18482    28
# 18483    26
# Name: email_len, Length: 18484, dtype: int64

# %%
dieci_più_lunghi = df.nlargest(10, 'email_len')
dieci_più_corti = df.nsmallest(10,'email_len')

# %%
dieci_più_lunghi
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title    FirstName  \
# 979          11979            69           AW00011979  None  christopher
# 1767         12767           648           AW00012767  None  christopher
# 2655         13655           609           AW00013655  None  christopher
# 3512         14512           633           AW00014512  None  christopher
# 4772         15772           361           AW00015772  None  christopher
# 4973         15973           638           AW00015973  None  christopher
# 7755         18755            50           AW00018755  None  christopher
# 8768         19768           310           AW00019768  None  christopher
# 9242         20242            18           AW00020242  None  christopher
# 10233        21233           358           AW00021233  None  christopher
#
#       MiddleName  LastName  NameStyle   BirthDate MaritalStatus  ...  \
# 979         None   JOHNSON          0  1962-11-05             M  ...
# ...

# %%
dieci_più_corti
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title FirstName  \
# 3974         14974           249           AW00014974   Mr.        k.
# 15299        26299           642           AW00026299  None        y.
# 8            11008            32           AW00011008  None       rob
# 53           11053           359           AW00011053  None       ana
# 215          11215            62           AW00011215  None       ana
# 550          11550           263           AW00011550  None       deb
# 710          11710           331           AW00011710  None       zoe
# 986          11986            34           AW00011986  None       max
# 1658         12658           279           AW00012658  None       joy
# 1899         12899           325           AW00012899  None       ana
#
#       MiddleName LastName  NameStyle   BirthDate MaritalStatus  ...  \
# 3974        None  SARAVAN          0  1984-12-29             S  ...
# ...

# %%
df['EmailLength'] = df['EmailAddress'].str.len()

dimcustomer_ordinati = df.sort_values(by='EmailLength', ascending=False)

top_10_lunghi = dimcustomer_ordinati.head(10)

top_10_corti = dimcustomer_ordinati.dropna(subset=['EmailAddress']).tail(10)

combined_results = pd.concat([top_10_lunghi, top_10_corti], keys=['Longest', 'Shortest'])

combined_results[['EmailAddress', 'EmailLength']]
# Out:
#                                      EmailAddress  EmailLength
# Longest  9242   christopher11@adventure-works.com           33
#          2655   christopher23@adventure-works.com           33
#          14964  christopher26@adventure-works.com           33
#          3512   christopher27@adventure-works.com           33
#          17017  christopher15@adventure-works.com           33
#          13417  christopher14@adventure-works.com           33
#          10233  christopher24@adventure-works.com           33
#          16661  christopher17@adventure-works.com           33
#          1767   christopher18@adventure-works.com           33
#          8768   christopher12@adventure-works.com           33
# Shortest 13515           ian4@adventure-works.com           24
#          10028           joe4@adventure-works.com           24
#          13583           roy2@adventure-works.com           24
#          4716            roy8@adventure-works.com           24
# ...

# %%
df['EmailAddress'] = df['EmailAddress'].str.replace('adventure-works.com', 'aw-db.com')

# %%
df['EmailAddress']
# Out:
# 0             jon24@aw-db.com
# 1          eugene10@aw-db.com
# 2           ruben35@aw-db.com
# 3         christy12@aw-db.com
# 4        elizabeth5@aw-db.com
#                  ...
# 18479        tommy2@aw-db.com
# 18480        nina21@aw-db.com
# 18481         ivan0@aw-db.com
# 18482      clayton0@aw-db.com
# 18483        jésus9@aw-db.com
# Name: EmailAddress, Length: 18484, dtype: object

# %%
address_with_street = df[df['AddressLine1'].str.contains('Street')]

# %%
address_with_street
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title FirstName  \
# 7            11007            40           AW00011007  None     marco
# 12           11012           611           AW00011012  None    lauren
# 32           11032            35           AW00011032  None    denise
# 63           11063           634           AW00011063  None    angela
# 125          11125            37           AW00011125  None      dana
# ...            ...           ...                  ...   ...       ...
# 18273        29273           298           AW00029273  None   timothy
# 18292        29292            34           AW00029292  None     diana
# 18323        29323            60           AW00029323  None    andrea
# 18333        29333            27           AW00029333  None      abby
# 18351        29351            49           AW00029351  None     jason
#
#       MiddleName   LastName  NameStyle   BirthDate MaritalStatus  ...  \
# ...

# %%
import pandas as pd
Facebook = pd.read_csv('../Dataset/beginner datasets 1/facebook.csv')

# %%
Facebook
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
Facebook.shape
# Out:
# (7050, 12)

# %%
Facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 661.1+ KB

# %%
Facebook.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
Facebook.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
Facebook.dtypes
# Out:
# status_id           object
# status_type         object
# status_published    object
# num_reactions        int64
# num_comments         int64
# num_shares           int64
# num_likes            int64
# num_loves            int64
# num_wows             int64
# num_hahas            int64
# num_sads             int64
# num_angrys           int64
# dtype: object

# %%
Facebook['status_published'] = pd.to_datetime(Facebook['status_published'])

# %%
Facebook
# Out:
#                               status_id status_type    status_published  \
# 0      246675545449582_1649696485147474       video 2018-04-22 06:00:00
# 1      246675545449582_1649426988507757       photo 2018-04-21 22:45:00
# 2      246675545449582_1648730588577397       video 2018-04-21 06:17:00
# 3      246675545449582_1648576705259452       photo 2018-04-21 02:29:00
# 4      246675545449582_1645700502213739       photo 2018-04-18 03:22:00
# ...                                 ...         ...                 ...
# 7045  1050855161656896_1061863470556065       photo 2016-09-24 02:58:00
# 7046  1050855161656896_1061334757275603       photo 2016-09-23 11:19:00
# 7047  1050855161656896_1060126464063099       photo 2016-09-21 23:03:00
# 7048  1050855161656896_1058663487542730       photo 2016-09-20 00:43:00
# 7049  1050855161656896_1050858841656528       photo 2016-09-10 10:30:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
Facebook['status_published'] = Facebook['status_published'].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
Facebook['status_published']
# Out:
# 0       2018-04-22 06:00:00
# 1       2018-04-21 22:45:00
# 2       2018-04-21 06:17:00
# 3       2018-04-21 02:29:00
# 4       2018-04-18 03:22:00
#                ...
# 7045    2016-09-24 02:58:00
# 7046    2016-09-23 11:19:00
# 7047    2016-09-21 23:03:00
# 7048    2016-09-20 00:43:00
# 7049    2016-09-10 10:30:00
# Name: status_published, Length: 7050, dtype: object

# %%
Facebook['status_published'].dt.year
# Out:
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
#         ...
# 7045    2016
# 7046    2016
# 7047    2016
# 7048    2016
# 7049    2016
# Name: status_published, Length: 7050, dtype: int32

# %%
Facebook['status_published'].dt.month
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 7045    9
# 7046    9
# 7047    9
# 7048    9
# 7049    9
# Name: status_published, Length: 7050, dtype: int32

# %%
Facebook['status_published'].dt.day
# Out:
# 0       22
# 1       21
# 2       21
# 3       21
# 4       18
#         ..
# 7045    24
# 7046    23
# 7047    21
# 7048    20
# 7049    10
# Name: status_published, Length: 7050, dtype: int32

# %%
Facebook['status_published'].dt.dayofweek
# Out:
# 0       6
# 1       5
# 2       5
# 3       5
# 4       2
#        ..
# 7045    5
# 7046    4
# 7047    2
# 7048    1
# 7049    5
# Name: status_published, Length: 7050, dtype: int32

# %%
Facebook['status_published'].dt.dayofyear
# Out:
# 0       112
# 1       111
# 2       111
# 3       111
# 4       108
#        ...
# 7045    268
# 7046    267
# 7047    265
# 7048    264
# 7049    254
# Name: status_published, Length: 7050, dtype: int32

# %%
Facebook_post_2012 = Facebook[Facebook['status_published'].dt.year == 2012]

# %%
Facebook_post_2012
# Out:
#                             status_id status_type    status_published  \
# 2046  246675545449582_303160673134402       photo 2012-12-23 03:11:00
# 2047  246675545449582_302341609882975       photo 2012-12-21 06:02:00
# 2048  246675545449582_299212316862571       photo 2012-12-13 11:36:00
# 2049  246675545449582_290159194434550       photo 2012-11-18 09:50:00
# 2050  246675545449582_290154177768385       photo 2012-11-18 09:16:00
# ...                               ...         ...                 ...
# 2630  246675545449582_246688625448274       photo 2012-07-15 03:54:00
# 2631  246675545449582_246686478781822       photo 2012-07-15 03:42:00
# 2632  246675545449582_246684432115360       photo 2012-07-15 03:32:00
# 2633  246675545449582_246678538782616       photo 2012-07-15 02:58:00
# 2634  246675545449582_246677465449390       photo 2012-07-15 02:51:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
Facebook_post_2018 = Facebook[(Facebook['status_published'].dt.year == 2018) & (Facebook['status_published'].dt.month == 5)]

# %%
Facebook_post_2018
# Out:
#                               status_id status_type    status_published  \
# 2690    134115277150304_264554297439734       photo 2018-05-31 12:17:00
# 2691    134115277150304_264493694112461       photo 2018-05-31 08:37:00
# 2692    134115277150304_264416247453539       photo 2018-05-31 03:12:00
# 2693    134115277150304_264168277478336       photo 2018-05-30 08:46:00
# 2694    134115277150304_264160757479088       photo 2018-05-30 08:24:00
# ...                                 ...         ...                 ...
# 6339  1050855161656896_1615666458509094        link 2018-05-04 01:27:00
# 6340  1050855161656896_1614717551937318       photo 2018-05-03 01:15:00
# 6341  1050855161656896_1614187798656960       photo 2018-05-02 12:17:00
# 6342  1050855161656896_1613063202102753       video 2018-05-01 08:38:00
# 6343  1050855161656896_1612778858797854       photo 2018-05-01 01:18:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
week_end_post = Facebook[(Facebook['status_published'].dt.dayofweek == 6) | (Facebook['status_published'].dt.dayofweek == 1)]
weekday_post = Facebook[(Facebook['status_published'].dt.dayofweek >= 2) & (Facebook['status_published'].dt.dayofweek <= 5)]

# %%
week_end_post
# Out:
#                               status_id status_type    status_published  \
# 0      246675545449582_1649696485147474       video 2018-04-22 06:00:00
# 7      246675545449582_1644824665634656       video 2018-04-17 07:42:00
# 8      246675545449582_1644655795651543       photo 2018-04-17 03:33:00
# 10     246675545449582_1637655039684952       photo 2018-04-10 01:01:00
# 12     246675545449582_1635846033199186       photo 2018-04-08 05:10:00
# ...                                 ...         ...                 ...
# 7031  1050855161656896_1075998879142524       photo 2016-10-11 05:53:00
# 7035  1050855161656896_1074576555951423       photo 2016-10-09 08:36:00
# 7037  1050855161656896_1070127156396363       photo 2016-10-04 01:49:00
# 7040  1050855161656896_1063071050435307       photo 2016-09-25 13:29:00
# 7048  1050855161656896_1058663487542730       photo 2016-09-20 00:43:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
weekday_post
# Out:
#                               status_id status_type    status_published  \
# 1      246675545449582_1649426988507757       photo 2018-04-21 22:45:00
# 2      246675545449582_1648730588577397       video 2018-04-21 06:17:00
# 3      246675545449582_1648576705259452       photo 2018-04-21 02:29:00
# 4      246675545449582_1645700502213739       photo 2018-04-18 03:22:00
# 5      246675545449582_1645650162218773       photo 2018-04-18 02:14:00
# ...                                 ...         ...                 ...
# 7044  1050855161656896_1061906620551750       photo 2016-09-24 04:37:00
# 7045  1050855161656896_1061863470556065       photo 2016-09-24 02:58:00
# 7046  1050855161656896_1061334757275603       photo 2016-09-23 11:19:00
# 7047  1050855161656896_1060126464063099       photo 2016-09-21 23:03:00
# 7049  1050855161656896_1050858841656528       photo 2016-09-10 10:30:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
Facebook['Tipo_giorno'] = Facebook['status_published'].dt.dayofweek.apply(lambda x: 'Weekend' if x >= 5 else 'Giorno feriale')

conteggio_post = Facebook['Tipo_giorno'].value_counts()

conteggio_post.to_frame()
# Out:
#                 count
# Tipo_giorno
# Giorno feriale   5009
# Weekend          2041

# %%
primo_post = Facebook.groupby(Facebook['status_published'].dt.year)['status_published'].min()
ultimo_post = Facebook.groupby(Facebook['status_published'].dt.year)['status_published'].max()

# %%
primo_post
# Out:
# status_published
# 2012   2012-07-15 02:51:00
# 2013   2013-01-02 02:23:00
# 2014   2014-01-05 09:23:00
# 2015   2015-01-02 03:41:00
# 2016   2016-01-03 04:23:00
# 2017   2017-01-02 08:25:00
# 2018   2018-01-01 01:39:00
# Name: status_published, dtype: datetime64[ns]

# %%
ultimo_post
# Out:
# status_published
# 2012   2012-12-23 03:11:00
# 2013   2013-12-31 23:38:00
# 2014   2014-12-10 07:42:00
# 2015   2015-12-31 08:20:00
# 2016   2016-12-31 05:13:00
# 2017   2017-12-31 22:15:00
# 2018   2018-06-13 01:12:00
# Name: status_published, dtype: datetime64[ns]

# %%
Facebook['status_published'] = Facebook['status_published'].dt.tz_localize('UTC')

# %%
Facebook['status_published']
# Out:
# 0      2018-04-22 06:00:00+00:00
# 1      2018-04-21 22:45:00+00:00
# 2      2018-04-21 06:17:00+00:00
# 3      2018-04-21 02:29:00+00:00
# 4      2018-04-18 03:22:00+00:00
#                   ...
# 7045   2016-09-24 02:58:00+00:00
# 7046   2016-09-23 11:19:00+00:00
# 7047   2016-09-21 23:03:00+00:00
# 7048   2016-09-20 00:43:00+00:00
# 7049   2016-09-10 10:30:00+00:00
# Name: status_published, Length: 7050, dtype: datetime64[ns, UTC]
