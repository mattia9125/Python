# %%
import pandas as pd 
import numpy as np

# %%
file_path = "../Dataset/Mappa-dei-pub-circoli-locali-in-Italia.json"

# %%
df = pd.read_json(file_path, encoding="latin1")

# %%
df
# Out:
#              ccomune             cprovincia  cregione            cnome  \
# 0              ALTRO                  ALTRO     ALTRO
# 1              ALTRO                  ALTRO     ALTRO      Lenny's Pub
# 2              ALTRO                  ALTRO     ALTRO  Murrayfield Pub
# 3              ALTRO                  ALTRO     ALTRO           Snop?e
# 4       Ala di Stura                 TORINO  Piemonte
# ...              ...                    ...       ...              ...
# 2492   Barletta (BT)  BARLETTA ANDRIA TRANI    Puglia      Santa Croce
# 2493  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia      Auld Dublin
# 2494  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia            Ferus
# 2495      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia          Re Artù
# 2496      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia     Well's Fargo
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 0                  2011    2011-06-25T23:17:43Z
# 1                  2011    2011-07-29T17:22:56Z
# ...

# %%
df.shape
# Out:
# (2497, 9)

# %%
df.describe()
# Out:
#        canno_inserimento  cidentificatore_in_openstreetmap  clongitudine  \
# count        2497.000000                      2.497000e+03   2497.000000
# mean         2012.816179                      1.847805e+09     11.412889
# std             1.915547                      1.057789e+09      2.381334
# min          2007.000000                      3.203094e+07      6.708958
# 25%          2012.000000                      9.195678e+08      9.214541
# 50%          2013.000000                      1.769765e+09     11.301761
# 75%          2014.000000                      2.616963e+09     12.682012
# max          2016.000000                      4.012443e+09     18.444577
#
#        clatitudine
# count  2497.000000
# mean     44.106531
# std       2.108361
# min      36.680786
# 25%      42.885316
# 50%      45.049664
# 75%      45.617151
# max      46.983781

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2497 entries, 0 to 2496
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ccomune                           2497 non-null   object
#  1   cprovincia                        2497 non-null   object
#  2   cregione                          2497 non-null   object
#  3   cnome                             2497 non-null   object
#  4   canno_inserimento                 2497 non-null   int64
#  5   cdata_e_ora_inserimento           2497 non-null   object
#  6   cidentificatore_in_openstreetmap  2497 non-null   int64
#  7   clongitudine                      2497 non-null   float64
#  8   clatitudine                       2497 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 175.7+ KB

# %%
df.dtypes
# Out:
# ccomune                              object
# cprovincia                           object
# cregione                             object
# cnome                                object
# canno_inserimento                     int64
# cdata_e_ora_inserimento              object
# cidentificatore_in_openstreetmap      int64
# clongitudine                        float64
# clatitudine                         float64
# dtype: object

# %%
df.columns = [col.lstrip('c') for col in df.columns]

# %%
df.rename(columns = {'omune': 'comune'}, inplace=True)

# %%
df
# Out:
#               comune              provincia   regione             nome  \
# 0              ALTRO                  ALTRO     ALTRO
# 1              ALTRO                  ALTRO     ALTRO      Lenny's Pub
# 2              ALTRO                  ALTRO     ALTRO  Murrayfield Pub
# 3              ALTRO                  ALTRO     ALTRO           Snop?e
# 4       Ala di Stura                 TORINO  Piemonte
# ...              ...                    ...       ...              ...
# 2492   Barletta (BT)  BARLETTA ANDRIA TRANI    Puglia      Santa Croce
# 2493  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia      Auld Dublin
# 2494  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia            Ferus
# 2495      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia          Re Artù
# 2496      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia     Well's Fargo
#
#       anno_inserimento data_e_ora_inserimento  \
# 0                 2011   2011-06-25T23:17:43Z
# 1                 2011   2011-07-29T17:22:56Z
# ...

# %%
df.dtypes
# Out:
# comune                              object
# provincia                           object
# regione                             object
# nome                                object
# anno_inserimento                     int64
# data_e_ora_inserimento              object
# identificatore_in_openstreetmap      int64
# longitudine                        float64
# latitudine                         float64
# dtype: object

# %%
df.iloc[0]
# Out:
# comune                                            ALTRO
# provincia                                         ALTRO
# regione                                           ALTRO
# nome
# anno_inserimento                                   2011
# data_e_ora_inserimento             2011-06-25T23:17:43Z
# identificatore_in_openstreetmap              1339088150
# longitudine                                   13.733257
# latitudine                                     45.57583
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# comune                                        Trani (BT)
# provincia                          BARLETTA ANDRIA TRANI
# regione                                           Puglia
# nome                                        Well's Fargo
# anno_inserimento                                    2009
# data_e_ora_inserimento              2009-08-10T12:44:03Z
# identificatore_in_openstreetmap                387223648
# longitudine                                    16.436765
# latitudine                                     41.267264
# Name: 2496, dtype: object

# %%
df.sample()
# Out:
#             comune provincia  regione          nome  anno_inserimento  \
# 2083  Guardiagrele    CHIETI  Abruzzo  Red Lion Pub              2014
#
#      data_e_ora_inserimento  identificatore_in_openstreetmap  longitudine  \
# 2083   2014-03-02T21:08:55Z                       2696457476    14.219121
#
#       latitudine
# 2083   42.197113

# %%
# per trovare quanti anni ci sono, bisogna indicare tra parentesi quadre la colonna di riferimento
# poi per i singoli attibuti presenti in colonna utilizzare la funzione unique()
df['anno_inserimento'].unique()
# Out:
# array([2011, 2015, 2010, 2012, 2014, 2016, 2013, 2008, 2009, 2007],
#       dtype=int64)

# %%
attività = (((df['longitudine'] >= 9) & (df['longitudine'] <=10)) & ((df['latitudine'] >= 45) & (df['longitudine'] <=46)))

# %%
len(df[attività])
# Out:
# 313

# %%
# quante attività ci sono nella provincia di Vicenza
attività_vicenza = df[df.provincia == 'VICENZA'].shape[0]

# %%
attività_vicenza
# Out:
# 73

# %%
# Quante enoteche ci sono e come si chiamano
num_enoteche = df.nome.replace('',np.nan).count()

# %%
num_enoteche
# Out:
# 2211

# %%
# quante attività ci sono in lazio e abruzzo insieme
regioni = df[df['regione'].isin(['Lazio','Abruzzo'])]
conteggio_regione = regioni.groupby('regione')['nome'].count()

# %%
conteggio_regione
# Out:
# regione
# Abruzzo     48
# Lazio      189
# Name: nome, dtype: int64

# %%
ins = pd.read_csv('../Dataset/beginner datasets 1/insurance.csv')

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins.shape
# Out:
# (1338, 7)

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
ins.sample(5)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 962   63  female  35.200         1     no  southeast  14474.67500
# 729   41  female  36.080         1     no  southeast   6781.35420
# 512   51    male  22.420         0     no  northeast   9361.32680
# 469   18  female  24.090         1     no  southeast   2201.09710
# 505   37    male  30.875         3     no  northwest   6796.86325

# %%
# Quali sono le medie di charges rispetto a region?
ins.groupby('region')['charges'].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
# E rispetto a smoker? E a sex?
ins.groupby('smoker')['charges'].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
ins.groupby('sex')['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
# Quali sono i descrittori statistici di bmi? 
# Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?
ins.groupby('bmi')['charges'].describe().transpose()
# Out:
# bmi       15.960       16.815       17.195        17.290      17.385  \
# count     1.0000     2.000000      1.00000      3.000000     1.00000
# mean   1694.7964  4904.000350  14455.64405   7813.353433  2775.19215
# std          NaN  2455.844784          NaN   4619.986089         NaN
# min    1694.7964  3167.455850  14455.64405   3732.625100  2775.19215
# 25%    1694.7964  4035.728100  14455.64405   5305.302600  2775.19215
# 50%    1694.7964  4904.000350  14455.64405   6877.980100  2775.19215
# 75%    1694.7964  5772.272600  14455.64405   9853.717600  2775.19215
# max    1694.7964  6640.544850  14455.64405  12829.455100  2775.19215
#
# bmi      17.400     17.480     17.670      17.765    17.800  ...      46.750  \
# count     1.000     1.0000     1.0000      1.0000     1.000  ...      1.0000
# mean   2585.269  1621.3402  2680.9493  32734.1863  1727.785  ...  12592.5345
# std         NaN        NaN        NaN         NaN       NaN  ...         NaN
# ...

# %%
import pandas as pd
iris = pd.read_csv('../Dataset/beginner datasets 1/iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.petal_length.mean()
# Out:
# 3.758666666666666

# %%
iris.groupby('species')['petal_length'].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
iris.groupby('species')['sepal_width'].agg(['mean','max','min'])
# Out:
#                   mean  max  min
# species
# Iris-setosa      3.418  4.4  2.3
# Iris-versicolor  2.770  3.4  2.0
# Iris-virginica   2.974  3.8  2.2

# %%
wine = pd.read_csv('../Dataset/beginner datasets 1/wine.csv')

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.groupby('quality')['alcohol'].mean()
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
wine['alcohol'].mean()
# Out:
# 10.491800831149453

# %%
wine.groupby('type')['alcoholì'].mean()
# Out:
# type
# red      10.422983
# white    10.514267
# Name: alcohol, dtype: float64

# %%
wine.groupby(['type','quality'])['pH'].mean()
# Out:
# type   quality
# red    3          3.398000
#        4          3.381509
#        5          3.304949
#        6          3.318072
#        7          3.290754
#        8          3.267222
# white  3          3.187500
#        4          3.182883
#        5          3.168833
#        6          3.188599
#        7          3.213898
#        8          3.218686
#        9          3.308000
# Name: pH, dtype: float64

# %%
wine.groupby(['type','quality'])['sulphates'].mean()
# Out:
# type   quality
# red    3          0.570000
#        4          0.596415
#        5          0.620969
#        6          0.675329
#        7          0.741256
#        8          0.767778
# white  3          0.474500
#        4          0.476135
#        5          0.482203
#        6          0.491106
#        7          0.503102
#        8          0.486229
#        9          0.466000
# Name: sulphates, dtype: float64

# %%
boston = pd.read_csv('../Dataset/beginner datasets 1/boston.csv')

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
boston.groupby('chas')['medv'].mean()
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
prezzo_medio = boston.groupby('crim')['medv'].mean()

# %%
(prezzo_medio*1000).round(0)
# Out:
# crim
# 0.00632     24000.0
# 0.00906     32200.0
# 0.01096     22000.0
# 0.01301     32700.0
# 0.01311     35400.0
#              ...
# 45.74610     7000.0
# 51.13580    15000.0
# 67.92080     5000.0
# 73.53410     8800.0
# 88.97620    10400.0
# Name: medv, Length: 504, dtype: float64

# %%
boston.groupby(['ptratio','medv'])['rm'].mean()
# Out:
# ptratio  medv
# 12.6     30.3    7.107
#          33.3    7.287
#          34.6    7.274
# 13.0     22.8    5.560
#          30.1    6.842
#                  ...
# 21.2     19.2    6.458
#          19.6    6.326
#          23.0    6.372
# 22.0     18.2    5.663
#          20.6    5.936
# Name: rm, Length: 440, dtype: float64

# %%
boston.loc[:,['crim','medv']].corr()
# Out:
#           crim      medv
# crim  1.000000 -0.388305
# medv -0.388305  1.000000

# %%
boston.loc[:,['crim','medv']].plot.scatter(x='crim', y='medv')
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %%
boston.groupby(['rad','rm','tax'])['age'].mean()
# Out:
# rad  rm     tax
# 1    5.706  304    28.4
#      5.876  315    19.1
#      6.030  273    80.8
#      6.031  304    23.3
#      6.108  315    32.0
#                    ...
# 24   7.016  666    97.5
#      7.061  666    77.0
#      7.313  666    97.9
#      7.393  666    99.3
#      8.780  666    82.9
# Name: age, Length: 495, dtype: float64
